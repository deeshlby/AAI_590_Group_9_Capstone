# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ### Read in the nutritional info metadata and define the columns. Select only those rows in the metadata for which there are images available.

# %%
# Define file paths for metadata and imagery folders
metadata_folder = 'nutrition5k_dataset/metadata/'
imagery_folder = 'nutrition5k_dataset/imagery/realsense_overhead/'

# Load metadata CSV files
metadata_cafe1 = pd.read_csv(os.path.join(metadata_folder, 'dish_metadata_cafe1.csv'), on_bad_lines='skip', header=None)
metadata_cafe2 = pd.read_csv(os.path.join(metadata_folder, 'dish_metadata_cafe2.csv'), on_bad_lines='skip', header=None)

# Combine both metadata files into one DataFrame
metadata = pd.concat([metadata_cafe1, metadata_cafe2], ignore_index=True)

# Display the first few rows to inspect the structure
display(metadata.head())

# Now, we know that the first column (column 0) is 'dish_id'
# Let's ensure it's a string, so we can match it to the image paths
metadata[0] = metadata[0].astype(str)

# Function to check if an image exists for a given dish_id.  Some dish_id have no associated imagery.
def image_exists(dish_id):
    image_path = os.path.join(imagery_folder, f'{dish_id}/rgb.png')
    return os.path.exists(image_path)

# Filter the metadata to retain only rows with a corresponding image
metadata_with_images = metadata[metadata[0].apply(image_exists)]

# Display the number of rows before and after filtering
display(f"Total rows in the metadata before filtering: {len(metadata)}")
display(f"Total rows in metadata after eliminating those without associated images: {len(metadata_with_images)}")
print("\n")

# Optionally, save the filtered metadata if needed
# metadata_with_images.to_csv('filtered_metadata.csv', index=False)

# Display the first few rows of the filtered metadata
print("First few rows of the combined metadata file, where there is a plate image corresponding to the dish_id.")
display(metadata_with_images.head())
# Out:
#                0           1      2          3          4          5    \
# 0  dish_1561662216  300.794281  193.0  12.387489  28.218290  18.633970
# 1  dish_1562688426  137.569992   88.0   8.256000   5.190000  10.297000
# 2  dish_1561662054  419.438782  292.0  23.838249  26.351543  25.910593
# 3  dish_1562008979  382.936646  290.0  22.224644  10.173570  35.345387
# 4  dish_1560455030   20.590000  103.0   0.148000   4.625000   0.956000
#
#                6                 7          8          9    ...       115  \
# 0  ingr_0000000508         soy sauce   3.398568   1.801241  ...  0.000425
# 1  ingr_0000000433  roasted potatoes  17.000000  23.970000  ...       NaN
# 2  ingr_0000000312            pepper   0.300716   0.120286  ...  0.000000
# 3  ingr_0000000448         jalapenos   0.192961   0.055959  ...       NaN
# 4  ingr_0000000471   cherry tomatoes  55.000000   9.900000  ...       NaN
#
#         116       117              118      119       120       121       122  \
# 0  0.019754  0.004248  ingr_0000000513   millet  3.414345  4.063071  0.034143
# 1       NaN       NaN              NaN      NaN       NaN       NaN       NaN
# 2  0.000000  0.000000  ingr_0000000524  parsley  0.752816  0.279295  0.006023
# 3       NaN       NaN              NaN      NaN       NaN       NaN       NaN
# 4       NaN       NaN              NaN      NaN       NaN       NaN       NaN
#
#        123       124
# 0  0.80920  0.119502
# 1      NaN       NaN
# 2  0.04818  0.021832
# 3      NaN       NaN
# 4      NaN       NaN
#
# [5 rows x 125 columns]
# 'Total rows in the metadata before filtering: 4583'
# 'Total rows in metadata after eliminating those without associated images: 3079'
# First few rows of the combined metadata file, where there is a plate image corresponding to the dish_id.
#                0           1      2          3          4          5    \
# 0  dish_1561662216  300.794281  193.0  12.387489  28.218290  18.633970
# 2  dish_1561662054  419.438782  292.0  23.838249  26.351543  25.910593
# 3  dish_1562008979  382.936646  290.0  22.224644  10.173570  35.345387
# 4  dish_1560455030   20.590000  103.0   0.148000   4.625000   0.956000
# 5  dish_1558372433   74.360001  143.0   0.286000   0.429000  20.020000
#
#                6                7           8          9    ...       115  \
# 0  ingr_0000000508        soy sauce    3.398568   1.801241  ...  0.000425
# 2  ingr_0000000312           pepper    0.300716   0.120286  ...  0.000000
# 3  ingr_0000000448        jalapenos    0.192961   0.055959  ...       NaN
# 4  ingr_0000000471  cherry tomatoes   55.000000   9.900000  ...       NaN
# 5  ingr_0000000453       deprecated  143.000000  74.360000  ...       NaN
#
#         116       117              118      119       120       121       122  \
# 0  0.019754  0.004248  ingr_0000000513   millet  3.414345  4.063071  0.034143
# 2  0.000000  0.000000  ingr_0000000524  parsley  0.752816  0.279295  0.006023
# 3       NaN       NaN              NaN      NaN       NaN       NaN       NaN
# 4       NaN       NaN              NaN      NaN       NaN       NaN       NaN
# 5       NaN       NaN              NaN      NaN       NaN       NaN       NaN
#
#        123       124
# 0  0.80920  0.119502
# 2  0.04818  0.021832
# 3      NaN       NaN
# 4      NaN       NaN
# 5      NaN       NaN
#
# [5 rows x 125 columns]

# %% [markdown]
# ### Obtain each image from the dataset folder, resize, normalize. OHE encode the image labels.

# %%
# Set folder path for images
image_folder = 'nutrition5k_dataset/imagery/realsense_overhead/'

# Image size for resizing
image_size = (224, 224)

# Lists to store images and labels
images = []
dish_ids = []

# Loop through each row in the metadata
for index, row in metadata.iterrows():
    # Since 'dish_id' is in the first column (column 0), we use row[0] instead of row['dish_id']
    dish_id = row[0]  # Accessing the first column of the row (which contains 'dish_id')
    
    # Construct the image path
    image_path = os.path.join(image_folder, dish_id, 'rgb.png')
    
    # Check if the image exists
    if os.path.exists(image_path):
        # Load the image
        image = cv2.imread(image_path)
        
        # Resize the image to a consistent size
        image = cv2.resize(image, image_size)
        
        # Convert the image to an array
        image = img_to_array(image)
        
        # Append the image and dish_id to the respective lists
        images.append(image)
        dish_ids.append(dish_id)

# Convert the lists to numpy arrays
images = np.array(images, dtype="float32") / 255.0  # Normalize pixel values to [0, 1]
dish_ids = np.array(dish_ids)

# Convert dish_ids to categorical labels
dish_id_labels = pd.Categorical(dish_ids).codes  # Convert dish_ids to numerical labels
dish_id_labels = to_categorical(dish_id_labels)  # One-hot encode the labels
num_dishes = dish_id_labels.shape[1]             # Determine the number of ingredients in each row

# Print the shapes of the resulting arrays
print(f"Images shape: {images.shape}")
print(f"Dish ID labels shape: {dish_id_labels.shape}")
# Out:
# Images shape: (3079, 224, 224, 3)
# Dish ID labels shape: (3079, 3079)

# %% [markdown]
# ### Train-test split.

# %%
# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, dish_id_labels, test_size=0.2, random_state=42)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (2463, 224, 224, 3)
# (2463, 3079)
# (616, 224, 224, 3)
# (616, 3079)

# %% [markdown]
# ### Model definition. Use data augmentation, Import base_model and set freezing layer. Customize Dense layers. Print number of model layers.

# %%
#from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD, RMSprop, AdamW
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.activations import hard_silu
from tensorflow.keras.regularizers import l1
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input

# Create an instance of ImageDataGenerator with augmentation.  Preprocess X_train for MobileNetV3.
datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)
train_generator = datagen.flow(X_train, y_train, batch_size=64)  # Set batch size

#Pre-process the X_test data, too. 
X_test = preprocess_input(X_test)

# Load pre-trained model without the top layer
base_model = MobileNetV3Large(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Set the number of layers for which the ImageNet weights will be preserved:
freeze_layer = 10
for layer in base_model.layers[:freeze_layer]:
    layer.trainable = False

# Set the rest of the layers to be fine-tuned on the training set.
for layer in base_model.layers[freeze_layer:]:
    layer.trainable = True

# Add custom layers on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dense(4096, activation='relu', kernel_regularizer=l1(1e-4), kernel_initializer='he_normal')(x)
x = Dropout(0.5)(x)
x = Dense(2048, activation='relu', kernel_regularizer=l1(1e-4))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu', kernel_regularizer=l1(1e-4))(x)
x = BatchNormalization()(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu', kernel_regularizer=l1(1e-4))(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(256, activation='relu', kernel_regularizer=l1(1e-4))(x)
x = Dropout(0.3)(x)
x = Dense(num_dishes, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=x)
print(f"The model has {len(model.layers)} layers total, of which {len(base_model.layers)} comes from the base_model.")
# Out:
# The model has 203 layers total, of which 187 comes from the base_model.

# %% [markdown]
# ### Set optimizer, LR, loss and metrics hyperparameters. Train the model.

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import TopKCategoricalAccuracy

early_stop = EarlyStopping(monitor='accuracy', patience=30, restore_best_weights=True)
lr_reduction = ReduceLROnPlateau(monitor='accuracy', patience=31, factor=0.8)

# Compile and train the model. Don't just use the top pick to calculate accuracy, but whether the correct pick was in the top 5.
optimizer = SGD(learning_rate=0.01, nesterov=True)
model.compile(optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy", TopKCategoricalAccuracy(k=5, name='top_5_categorical_accuracy')])

history = model.fit(train_generator, validation_data=(X_test, y_test), epochs=100, callbacks=[early_stop, lr_reduction])
# Out:
# Epoch 1/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 51s 614ms/step - accuracy: 5.8113e-04 - loss: 41.7536 - top_5_categorical_accuracy: 0.0031 - val_accuracy: 0.0000e+00 - val_loss: 41.7213 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 2/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 47s 610ms/step - accuracy: 0.0000e+00 - loss: 41.6240 - top_5_categorical_accuracy: 0.0023 - val_accuracy: 0.0000e+00 - val_loss: 41.6203 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 3/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 621ms/step - accuracy: 7.2633e-05 - loss: 41.5224 - top_5_categorical_accuracy: 0.0027 - val_accuracy: 0.0000e+00 - val_loss: 41.5142 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 4/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 617ms/step - accuracy: 0.0000e+00 - loss: 41.3829 - top_5_categorical_accuracy: 0.0012 - val_accuracy: 0.0000e+00 - val_loss: 41.4032 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 5/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 618ms/step - accuracy: 3.0118e-04 - loss: 41.2901 - top_5_categorical_accuracy: 6.0112e-04 - val_accuracy: 0.0000e+00 - val_loss: 41.3121 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 6/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 624ms/step - accuracy: 2.6535e-04 - loss: 41.1719 - top_5_categorical_accuracy: 0.0025 - val_accuracy: 0.0000e+00 - val_loss: 41.1994 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 7/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 47s 611ms/step - accuracy: 6.2496e-04 - loss: 41.0490 - top_5_categorical_accuracy: 0.0047 - val_accuracy: 0.0000e+00 - val_loss: 41.1002 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 8/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 616ms/step - accuracy: 4.8871e-05 - loss: 40.9347 - top_5_categorical_accuracy: 0.0025 - val_accuracy: 0.0000e+00 - val_loss: 40.9914 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 9/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 47s 615ms/step - accuracy: 0.0019 - loss: 40.8162 - top_5_categorical_accuracy: 0.0035 - val_accuracy: 0.0000e+00 - val_loss: 40.8869 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 10/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 624ms/step - accuracy: 9.6170e-04 - loss: 40.7165 - top_5_categorical_accuracy: 0.0015 - val_accuracy: 0.0000e+00 - val_loss: 40.7863 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 11/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 621ms/step - accuracy: 0.0000e+00 - loss: 40.6186 - top_5_categorical_accuracy: 0.0012 - val_accuracy: 0.0000e+00 - val_loss: 40.6794 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 12/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 623ms/step - accuracy: 6.0564e-05 - loss: 40.4700 - top_5_categorical_accuracy: 0.0026 - val_accuracy: 0.0000e+00 - val_loss: 40.5749 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 13/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 626ms/step - accuracy: 0.0026 - loss: 40.3805 - top_5_categorical_accuracy: 0.0073 - val_accuracy: 0.0000e+00 - val_loss: 40.4722 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 14/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 623ms/step - accuracy: 5.5847e-04 - loss: 40.2676 - top_5_categorical_accuracy: 0.0022 - val_accuracy: 0.0000e+00 - val_loss: 40.3627 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 15/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 627ms/step - accuracy: 0.0000e+00 - loss: 40.1578 - top_5_categorical_accuracy: 5.4327e-04 - val_accuracy: 0.0000e+00 - val_loss: 40.2865 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 16/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 625ms/step - accuracy: 0.0013 - loss: 40.0464 - top_5_categorical_accuracy: 0.0033 - val_accuracy: 0.0000e+00 - val_loss: 40.1810 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 17/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 630ms/step - accuracy: 6.7670e-04 - loss: 39.9159 - top_5_categorical_accuracy: 0.0045 - val_accuracy: 0.0000e+00 - val_loss: 40.0803 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 18/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 635ms/step - accuracy: 4.5054e-04 - loss: 39.8377 - top_5_categorical_accuracy: 0.0014 - val_accuracy: 0.0000e+00 - val_loss: 39.9693 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 19/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 620ms/step - accuracy: 0.0015 - loss: 39.6808 - top_5_categorical_accuracy: 0.0069 - val_accuracy: 0.0000e+00 - val_loss: 39.8667 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 20/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 621ms/step - accuracy: 0.0000e+00 - loss: 39.5964 - top_5_categorical_accuracy: 0.0031 - val_accuracy: 0.0000e+00 - val_loss: 39.7766 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 21/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 630ms/step - accuracy: 0.0018 - loss: 39.4990 - top_5_categorical_accuracy: 0.0031 - val_accuracy: 0.0000e+00 - val_loss: 39.6725 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 22/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 620ms/step - accuracy: 4.3238e-04 - loss: 39.3796 - top_5_categorical_accuracy: 0.0042 - val_accuracy: 0.0000e+00 - val_loss: 39.5539 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 23/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 619ms/step - accuracy: 7.0562e-04 - loss: 39.2496 - top_5_categorical_accuracy: 0.0021 - val_accuracy: 0.0000e+00 - val_loss: 39.4598 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 24/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 624ms/step - accuracy: 1.0446e-04 - loss: 39.1419 - top_5_categorical_accuracy: 0.0035 - val_accuracy: 0.0000e+00 - val_loss: 39.3749 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 25/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 630ms/step - accuracy: 0.0000e+00 - loss: 39.0463 - top_5_categorical_accuracy: 0.0026 - val_accuracy: 0.0000e+00 - val_loss: 39.2666 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 26/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 627ms/step - accuracy: 1.0446e-04 - loss: 38.9294 - top_5_categorical_accuracy: 4.3302e-04 - val_accuracy: 0.0000e+00 - val_loss: 39.1427 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 27/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 625ms/step - accuracy: 7.0604e-04 - loss: 38.8052 - top_5_categorical_accuracy: 0.0074 - val_accuracy: 0.0000e+00 - val_loss: 39.0455 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 28/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 628ms/step - accuracy: 0.0000e+00 - loss: 38.7181 - top_5_categorical_accuracy: 3.5411e-04 - val_accuracy: 0.0000e+00 - val_loss: 38.9412 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 29/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 629ms/step - accuracy: 0.0011 - loss: 38.5760 - top_5_categorical_accuracy: 0.0027 - val_accuracy: 0.0000e+00 - val_loss: 38.8432 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 30/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 627ms/step - accuracy: 3.1818e-04 - loss: 38.4767 - top_5_categorical_accuracy: 0.0039 - val_accuracy: 0.0000e+00 - val_loss: 38.7549 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 31/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 620ms/step - accuracy: 9.9758e-04 - loss: 38.3477 - top_5_categorical_accuracy: 0.0029 - val_accuracy: 0.0000e+00 - val_loss: 38.6746 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 32/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 619ms/step - accuracy: 6.8431e-04 - loss: 38.2273 - top_5_categorical_accuracy: 0.0062 - val_accuracy: 0.0000e+00 - val_loss: 38.5730 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 33/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 623ms/step - accuracy: 0.0011 - loss: 38.1243 - top_5_categorical_accuracy: 0.0067 - val_accuracy: 0.0000e+00 - val_loss: 38.4846 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 34/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 620ms/step - accuracy: 9.9791e-04 - loss: 37.9944 - top_5_categorical_accuracy: 0.0034 - val_accuracy: 0.0000e+00 - val_loss: 38.3567 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 35/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 617ms/step - accuracy: 0.0015 - loss: 37.8762 - top_5_categorical_accuracy: 0.0057 - val_accuracy: 0.0000e+00 - val_loss: 38.2610 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 36/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 624ms/step - accuracy: 0.0000e+00 - loss: 37.7765 - top_5_categorical_accuracy: 0.0019 - val_accuracy: 0.0000e+00 - val_loss: 38.1730 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 37/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 620ms/step - accuracy: 0.0000e+00 - loss: 37.6146 - top_5_categorical_accuracy: 0.0050 - val_accuracy: 0.0000e+00 - val_loss: 38.1027 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 38/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 47s 614ms/step - accuracy: 3.9243e-04 - loss: 37.5031 - top_5_categorical_accuracy: 0.0018 - val_accuracy: 0.0000e+00 - val_loss: 38.0099 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 39/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 624ms/step - accuracy: 0.0025 - loss: 37.3926 - top_5_categorical_accuracy: 0.0063 - val_accuracy: 0.0000e+00 - val_loss: 37.9407 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 40/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 618ms/step - accuracy: 0.0014 - loss: 37.2633 - top_5_categorical_accuracy: 0.0053 - val_accuracy: 0.0000e+00 - val_loss: 37.8124 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 41/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 622ms/step - accuracy: 0.0029 - loss: 37.1631 - top_5_categorical_accuracy: 0.0069 - val_accuracy: 0.0000e+00 - val_loss: 37.7472 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 42/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 631ms/step - accuracy: 2.1868e-04 - loss: 37.0275 - top_5_categorical_accuracy: 0.0044 - val_accuracy: 0.0000e+00 - val_loss: 37.6570 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 43/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 625ms/step - accuracy: 0.0028 - loss: 36.8980 - top_5_categorical_accuracy: 0.0070 - val_accuracy: 0.0000e+00 - val_loss: 37.5678 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 44/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 617ms/step - accuracy: 0.0012 - loss: 36.7437 - top_5_categorical_accuracy: 0.0087 - val_accuracy: 0.0000e+00 - val_loss: 37.4858 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 45/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 627ms/step - accuracy: 0.0010 - loss: 36.6408 - top_5_categorical_accuracy: 0.0089 - val_accuracy: 0.0000e+00 - val_loss: 37.3729 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 46/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 623ms/step - accuracy: 9.8168e-04 - loss: 36.5247 - top_5_categorical_accuracy: 0.0055 - val_accuracy: 0.0000e+00 - val_loss: 37.3912 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 47/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 623ms/step - accuracy: 0.0013 - loss: 36.3742 - top_5_categorical_accuracy: 0.0074 - val_accuracy: 0.0000e+00 - val_loss: 37.3492 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 48/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 628ms/step - accuracy: 0.0032 - loss: 36.2462 - top_5_categorical_accuracy: 0.0064 - val_accuracy: 0.0000e+00 - val_loss: 37.1653 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 49/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 623ms/step - accuracy: 0.0028 - loss: 36.1116 - top_5_categorical_accuracy: 0.0095 - val_accuracy: 0.0000e+00 - val_loss: 37.0664 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 50/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 622ms/step - accuracy: 0.0012 - loss: 35.9915 - top_5_categorical_accuracy: 0.0029 - val_accuracy: 0.0000e+00 - val_loss: 37.0096 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 51/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 47s 610ms/step - accuracy: 0.0019 - loss: 35.8540 - top_5_categorical_accuracy: 0.0084 - val_accuracy: 0.0000e+00 - val_loss: 36.8763 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 52/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 621ms/step - accuracy: 0.0035 - loss: 35.7403 - top_5_categorical_accuracy: 0.0079 - val_accuracy: 0.0000e+00 - val_loss: 36.7844 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 53/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 621ms/step - accuracy: 0.0023 - loss: 35.6146 - top_5_categorical_accuracy: 0.0137 - val_accuracy: 0.0000e+00 - val_loss: 36.6917 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 54/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 619ms/step - accuracy: 0.0014 - loss: 35.4684 - top_5_categorical_accuracy: 0.0157 - val_accuracy: 0.0000e+00 - val_loss: 36.6136 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 55/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 47s 613ms/step - accuracy: 0.0032 - loss: 35.3577 - top_5_categorical_accuracy: 0.0099 - val_accuracy: 0.0000e+00 - val_loss: 36.5648 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 56/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 47s 614ms/step - accuracy: 1.2480e-04 - loss: 35.2273 - top_5_categorical_accuracy: 0.0056 - val_accuracy: 0.0000e+00 - val_loss: 36.5000 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 57/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 47s 613ms/step - accuracy: 0.0016 - loss: 35.0860 - top_5_categorical_accuracy: 0.0104 - val_accuracy: 0.0000e+00 - val_loss: 36.4623 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 58/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 47s 610ms/step - accuracy: 0.0028 - loss: 34.9405 - top_5_categorical_accuracy: 0.0144 - val_accuracy: 0.0000e+00 - val_loss: 36.5114 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 59/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 622ms/step - accuracy: 0.0020 - loss: 34.8191 - top_5_categorical_accuracy: 0.0080 - val_accuracy: 0.0000e+00 - val_loss: 36.4478 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 60/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 622ms/step - accuracy: 0.0027 - loss: 34.6975 - top_5_categorical_accuracy: 0.0134 - val_accuracy: 0.0000e+00 - val_loss: 36.4625 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 61/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 628ms/step - accuracy: 0.0027 - loss: 34.5271 - top_5_categorical_accuracy: 0.0129 - val_accuracy: 0.0000e+00 - val_loss: 36.5495 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 62/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 620ms/step - accuracy: 0.0011 - loss: 34.4239 - top_5_categorical_accuracy: 0.0084 - val_accuracy: 0.0000e+00 - val_loss: 36.4160 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 63/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 628ms/step - accuracy: 3.7797e-04 - loss: 34.3101 - top_5_categorical_accuracy: 0.0080 - val_accuracy: 0.0000e+00 - val_loss: 36.2317 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 64/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 626ms/step - accuracy: 0.0027 - loss: 34.1375 - top_5_categorical_accuracy: 0.0111 - val_accuracy: 0.0000e+00 - val_loss: 36.1370 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 65/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 632ms/step - accuracy: 0.0032 - loss: 34.0385 - top_5_categorical_accuracy: 0.0162 - val_accuracy: 0.0000e+00 - val_loss: 36.1866 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 66/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 631ms/step - accuracy: 0.0019 - loss: 33.8985 - top_5_categorical_accuracy: 0.0144 - val_accuracy: 0.0000e+00 - val_loss: 36.3534 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 67/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 634ms/step - accuracy: 0.0020 - loss: 33.7677 - top_5_categorical_accuracy: 0.0132 - val_accuracy: 0.0000e+00 - val_loss: 36.3674 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 68/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 623ms/step - accuracy: 0.0035 - loss: 33.6477 - top_5_categorical_accuracy: 0.0146 - val_accuracy: 0.0000e+00 - val_loss: 36.3371 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 69/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 623ms/step - accuracy: 0.0054 - loss: 33.4868 - top_5_categorical_accuracy: 0.0167 - val_accuracy: 0.0000e+00 - val_loss: 36.7892 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 70/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 630ms/step - accuracy: 0.0035 - loss: 33.3452 - top_5_categorical_accuracy: 0.0185 - val_accuracy: 0.0000e+00 - val_loss: 36.6249 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 71/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 618ms/step - accuracy: 0.0038 - loss: 33.2194 - top_5_categorical_accuracy: 0.0151 - val_accuracy: 0.0000e+00 - val_loss: 36.2420 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 72/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 627ms/step - accuracy: 0.0044 - loss: 33.0911 - top_5_categorical_accuracy: 0.0204 - val_accuracy: 0.0000e+00 - val_loss: 36.3261 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 73/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 627ms/step - accuracy: 0.0049 - loss: 32.8879 - top_5_categorical_accuracy: 0.0329 - val_accuracy: 0.0000e+00 - val_loss: 36.3520 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 74/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 626ms/step - accuracy: 0.0052 - loss: 32.8280 - top_5_categorical_accuracy: 0.0217 - val_accuracy: 0.0000e+00 - val_loss: 36.4542 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 75/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 626ms/step - accuracy: 0.0056 - loss: 32.6764 - top_5_categorical_accuracy: 0.0218 - val_accuracy: 0.0000e+00 - val_loss: 36.0137 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 76/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 622ms/step - accuracy: 0.0061 - loss: 32.5414 - top_5_categorical_accuracy: 0.0279 - val_accuracy: 0.0000e+00 - val_loss: 36.1549 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 77/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 623ms/step - accuracy: 0.0091 - loss: 32.3727 - top_5_categorical_accuracy: 0.0258 - val_accuracy: 0.0000e+00 - val_loss: 36.3668 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 78/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 620ms/step - accuracy: 0.0053 - loss: 32.2780 - top_5_categorical_accuracy: 0.0283 - val_accuracy: 0.0000e+00 - val_loss: 36.2495 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 79/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 620ms/step - accuracy: 0.0042 - loss: 32.1431 - top_5_categorical_accuracy: 0.0213 - val_accuracy: 0.0000e+00 - val_loss: 35.8409 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 80/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 618ms/step - accuracy: 0.0069 - loss: 32.0036 - top_5_categorical_accuracy: 0.0301 - val_accuracy: 0.0000e+00 - val_loss: 35.6106 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 81/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 621ms/step - accuracy: 0.0070 - loss: 31.8614 - top_5_categorical_accuracy: 0.0302 - val_accuracy: 0.0000e+00 - val_loss: 35.5015 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 82/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 620ms/step - accuracy: 0.0133 - loss: 31.7243 - top_5_categorical_accuracy: 0.0356 - val_accuracy: 0.0000e+00 - val_loss: 35.6299 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 83/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 623ms/step - accuracy: 0.0061 - loss: 31.6052 - top_5_categorical_accuracy: 0.0288 - val_accuracy: 0.0000e+00 - val_loss: 35.1021 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 84/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 627ms/step - accuracy: 0.0066 - loss: 31.5058 - top_5_categorical_accuracy: 0.0302 - val_accuracy: 0.0000e+00 - val_loss: 35.0360 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 85/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 629ms/step - accuracy: 0.0076 - loss: 31.2736 - top_5_categorical_accuracy: 0.0426 - val_accuracy: 0.0000e+00 - val_loss: 35.2997 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 86/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 47s 615ms/step - accuracy: 0.0132 - loss: 31.1741 - top_5_categorical_accuracy: 0.0541 - val_accuracy: 0.0000e+00 - val_loss: 35.2746 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 87/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 620ms/step - accuracy: 0.0103 - loss: 31.0711 - top_5_categorical_accuracy: 0.0375 - val_accuracy: 0.0000e+00 - val_loss: 35.4430 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 88/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 620ms/step - accuracy: 0.0057 - loss: 30.9595 - top_5_categorical_accuracy: 0.0359 - val_accuracy: 0.0000e+00 - val_loss: 35.5292 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 89/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 621ms/step - accuracy: 0.0057 - loss: 30.7744 - top_5_categorical_accuracy: 0.0426 - val_accuracy: 0.0000e+00 - val_loss: 35.6606 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 90/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 619ms/step - accuracy: 0.0056 - loss: 30.6011 - top_5_categorical_accuracy: 0.0359 - val_accuracy: 0.0000e+00 - val_loss: 35.8208 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 91/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 625ms/step - accuracy: 0.0131 - loss: 30.5163 - top_5_categorical_accuracy: 0.0580 - val_accuracy: 0.0000e+00 - val_loss: 36.1853 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 92/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 620ms/step - accuracy: 0.0107 - loss: 30.4136 - top_5_categorical_accuracy: 0.0480 - val_accuracy: 0.0000e+00 - val_loss: 36.0021 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 93/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 626ms/step - accuracy: 0.0083 - loss: 30.2924 - top_5_categorical_accuracy: 0.0556 - val_accuracy: 0.0000e+00 - val_loss: 36.9276 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 94/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 624ms/step - accuracy: 0.0105 - loss: 30.0819 - top_5_categorical_accuracy: 0.0559 - val_accuracy: 0.0000e+00 - val_loss: 35.7456 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 95/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 622ms/step - accuracy: 0.0125 - loss: 30.0247 - top_5_categorical_accuracy: 0.0539 - val_accuracy: 0.0000e+00 - val_loss: 35.7153 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 96/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 634ms/step - accuracy: 0.0060 - loss: 29.8846 - top_5_categorical_accuracy: 0.0633 - val_accuracy: 0.0000e+00 - val_loss: 35.9585 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 97/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 631ms/step - accuracy: 0.0083 - loss: 29.7576 - top_5_categorical_accuracy: 0.0562 - val_accuracy: 0.0000e+00 - val_loss: 36.6242 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 98/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 48s 624ms/step - accuracy: 0.0124 - loss: 29.6110 - top_5_categorical_accuracy: 0.0585 - val_accuracy: 0.0000e+00 - val_loss: 35.8299 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 99/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 632ms/step - accuracy: 0.0119 - loss: 29.4716 - top_5_categorical_accuracy: 0.0618 - val_accuracy: 0.0000e+00 - val_loss: 36.0354 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100
# Epoch 100/100
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 49s 633ms/step - accuracy: 0.0206 - loss: 29.3355 - top_5_categorical_accuracy: 0.0722 - val_accuracy: 0.0000e+00 - val_loss: 35.2432 - val_top_5_categorical_accuracy: 0.0000e+00 - learning_rate: 0.0100

# %% [markdown]
# ### Plot training and validation accuracy and loss.

# %%
# Get training and validation accuracy/loss from the history object
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
train_top5_acc = history.history['top_5_categorical_accuracy']
val_top5_acc = history.history['val_top_5_categorical_accuracy']

# Get number of epochs
epochs = range(1, len(accuracy) + 1)

# Plot training and validation accuracy and loss side-by-side
plt.figure(figsize=(14, 5))

# Plot training and validation accuracy
plt.subplot(1, 2, 1)
plt.plot(epochs, accuracy, 'bo-', label='Training Accuracy')  # Blue for training accuracy
plt.plot(epochs, train_top5_acc, 'o-', color='orange', label='Top 5 Categorical Accuracy')  # Orange for validation accuracy
plt.plot(epochs, val_top5_acc, 'o-', color='green', label='Validation Top 5 Categorical Accuracy')  # Green for top_K_validation accuracy
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo-', label='Training Loss')  # Blue for training loss
plt.plot(epochs, val_loss, 'o-', color='orange', label='Validation Loss')  # Orange for validation loss
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Automatically adjust layout to fit everything
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ### Define functions to get glycemic index data from glycemic_index.xlsx; from the prediction, get nutritional info; display nutritional information.

# %%
import cv2
import pandas as pd

# Load the glycemic index data from the Excel file (this assumes glycemic_index.xlsx exists)
gi_data = pd.read_excel("glycemic_index.xlsx")

# Create a dictionary from the Excel file for quick lookup
gi_dict = pd.Series(gi_data['Glycemic index'].values, index=gi_data['Item']).to_dict()

# Predict dish_id from an image
def predict_dish(image):
    image = cv2.resize(image, image_size)  # Resize to match the input shape
    image = np.expand_dims(image, axis=0)  # Add batch dimension
    image = image.astype("float32") / 255.0  # Normalize

    # Predict dish ID
    prediction = model.predict(image)
    dish_index = np.argmax(prediction)  # Get the predicted dish index
    predicted_dish_id = pd.Categorical(dish_ids).categories[dish_index]
    
    # Retrieve nutritional info based on predicted dish_id
    nutrition_info = metadata[metadata[0] == predicted_dish_id]

    if nutrition_info.empty:
        return predicted_dish_id, None  # Return None if no matching dish_id is found

    return predicted_dish_id, nutrition_info.iloc[0]

# Function to get glycemic index from the Excel data
def get_glycemic_index(ingredient):
    # Normalize ingredient names for case-insensitive matching
    ingredient_lower = ingredient.lower()
    gi_dict_lower = {k.lower(): v for k, v in gi_dict.items()}

    # Return the glycemic index if present in the Excel data
    if ingredient_lower in gi_dict_lower:
        return gi_dict_lower[ingredient_lower]
    else:
        return "GI not available"

# Function to calculate the weighted glycemic index for the entire dish
def calculate_weighted_gi(ingredients_info):
    total_weight = 0  # Sum of all ingredient masses
    weighted_sum_gi = 0  # To accumulate the weighted sum of GIs

    # Loop through each ingredient information tuple (ID, Name, Mass, Calories, Fat, Carbs, Protein)
    for ingredient_info in ingredients_info:
        ingredient_name = ingredient_info[1]
        ingredient_mass = ingredient_info[2]
        
        # Get the glycemic index for the ingredient
        gi_value = get_glycemic_index(ingredient_name)
        
        # If GI is available and valid, add to the weighted sum
        if isinstance(gi_value, (int, float)):
            weighted_sum_gi += gi_value * ingredient_mass
            total_weight += ingredient_mass
        else:
            print(f"Warning: {gi_value} for {ingredient_name}")

    # Calculate the weighted average GI
    if total_weight > 0:
        weighted_avg_gi = weighted_sum_gi / total_weight
        return weighted_avg_gi
    else:
        return "Total weight is zero, cannot calculate weighted average."

# Function to display nutritional info and calculate GI
def display_nutrition_info(nutrition_info):

    column_names = [
        'Dish ID', 'Total Calories', 'Total Mass', 'Total Fat', 'Total Carbohydrates', 'Total Protein'
    ]
    
    # Display basic nutritional info
    print("=== Dish Nutritional Information ===")
    for i, column in enumerate(column_names):
        print(f"{column}: {nutrition_info[i]}")

    # Display ingredients and their nutritional info
    print("\n=== Ingredients Information ===")
    ingredient_offset = 6  # Ingredients start from the 7th column (index 6)
    ingredient_number = 1
    ingredients_info = []  # To store ingredient information for GI calculation

    while ingredient_offset < len(nutrition_info):
        # Check if the ingredient name is NaN, which indicates no more ingredients
        if pd.isna(nutrition_info[ingredient_offset + 1]):
            break
        
        # Extract ingredient information
        ingredient_id = nutrition_info[ingredient_offset]
        ingredient_name = nutrition_info[ingredient_offset + 1]
        ingredient_mass = nutrition_info[ingredient_offset + 2]
        ingredient_calories = nutrition_info[ingredient_offset + 3]
        ingredient_fat = nutrition_info[ingredient_offset + 4]
        ingredient_carbs = nutrition_info[ingredient_offset + 5]
        ingredient_protein = nutrition_info[ingredient_offset + 6]

        print(f"\nIngredient {ingredient_number}:")
        print(f"  Ingredient ID: {ingredient_id}")
        print(f"  Ingredient Name: {ingredient_name}")
        print(f"  Ingredient Grams: {ingredient_mass}")
        print(f"  Ingredient Calories: {ingredient_calories}")
        print(f"  Ingredient Fat: {ingredient_fat}")
        print(f"  Ingredient Carbohydrates: {ingredient_carbs}")
        print(f"  Ingredient Protein: {ingredient_protein}")

        # Get the glycemic index for this ingredient
        gi_value = get_glycemic_index(ingredient_name)
        print(f"  Glycemic Index: {gi_value}")

        # Store ingredient info for weighted GI calculation
        ingredients_info.append((
            ingredient_id, ingredient_name, ingredient_mass, ingredient_calories, ingredient_fat, ingredient_carbs, ingredient_protein
        ))

        # Move to the next ingredient (each ingredient has 7 columns)
        ingredient_offset += 7
        ingredient_number += 1

    # Calculate and display the weighted average glycemic index for the dish
    weighted_avg_gi = calculate_weighted_gi(ingredients_info)
    print(f"\nThe Weighted Average Glycemic Index for the entire dish is: {weighted_avg_gi}")

# Main function to process an image and predict the nutritional info
def process_dish_image(img_path):
    img = cv2.imread(img_path)
    
    # Plot the image
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(6, 6)) 
    plt.imshow(img_rgb)
    plt.title("Plate of food to be predicted on")  
    plt.axis('off')  
    plt.show()

    # Predict the dish ID and nutrition info using the model
    dish_id, nutrition_info = predict_dish(img) 

    # Output the predicted dish ID
    print(f"Predicted Dish ID: {dish_id}")
    
    # Display the nutritional information and calculate GI
    display_nutrition_info(nutrition_info)

# %% [markdown]
# ### Make a prediction on an image in the dataset.

# %%
# Select an image from the realsense_overhead folder and make a prediction.
img_path = 'nutrition5k_dataset/imagery/realsense_overhead/dish_1556572657/rgb.png'
process_dish_image(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# Predicted Dish ID: dish_1558721380
# === Dish Nutritional Information ===
# Dish ID: dish_1558721380
# Total Calories: 19.26
# Total Mass: 107.0
# Total Fat: 0.214
# Total Carbohydrates: 4.173
# Total Protein: 0.963
#
# === Ingredients Information ===
#
# Ingredient 1:
#   Ingredient ID: ingr_0000000471
#   Ingredient Name: cherry tomatoes
#   Ingredient Grams: 107.0
#   Ingredient Calories: 19.26
#   Ingredient Fat: 0.214
#   Ingredient Carbohydrates: 4.173
#   Ingredient Protein: 0.963
#   Glycemic Index: 15.0
#
# The Weighted Average Glycemic Index for the entire dish is: 15.0

# %% [markdown]
# ### This code was just used to print all the ingredients in the dataset.  Ignore.

# %%
# Initialize a set to store unique ingredient names (to avoid duplicates)
unique_ingredients = set()

# Ingredients start at column 7 (ingredient 1 name), and each ingredient block has 7 columns
ingredient_name_col_start = 7
num_columns = metadata.shape[1]  # Number of columns in the metadata

# Loop over each row in the existing metadata DataFrame
for _, row in metadata.iterrows():
    # Iterate through the ingredient columns, stepping by 7 columns (each ingredient block)
    for col in range(ingredient_name_col_start, num_columns, 7):
        ingredient_name = row[col]  # This is the ingredient name

        # Check if the ingredient name is valid (not NaN or empty)
        if pd.notna(ingredient_name) and ingredient_name != '':
            unique_ingredients.add(ingredient_name)

# Convert the set to a sorted list for better readability
sorted_ingredients = sorted(unique_ingredients)

# Print all the unique ingredients
print("List of unique ingredients in the metadata:")
# for ingredient in sorted_ingredients:
#    print(ingredient)
